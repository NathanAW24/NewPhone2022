# %% [markdown]
# # Question: Which phone is the most worth to buy?
# The most worth phone is defined as the cheapest phone possible which still fulfills the minimum criteria.

# %%
import pandas as pd

# %%
phoneSpecs_file = 'SpecsWebsites\phoneSpecs.csv'
phoneWeb_file = 'OfficialWebsites\OfficialWeb_Phones.csv'

# %%
df_specs = pd.read_csv(phoneSpecs_file)
df_specs.head()
# Out:
#                                                  CPU  \
# 0  Hexa-core (2x3.22 GHz Avalanche + 4xX.X GHz Bl...
# 1  Hexa-core (2x3.22 GHz Avalanche + 4xX.X GHz Bl...
# 2  Hexa-core (2x3.1 GHz Firestorm + 4x1.8 GHz Ice...
# 3  Hexa-core (2x2.65 GHz Lightning + 4x1.8 GHz Th...
# 4  Hexa-core (2x2.65 GHz Lightning + 4x1.8 GHz Th...
#
#                            GPU  NFC                                OS  RAM  \
# 0  Apple GPU (5-core graphics)  Yes    iOS 15, upgradable to iOS 15.2  6GB
# 1  Apple GPU (4-core graphics)  Yes    iOS 15, upgradable to iOS 15.2  4GB
# 2  Apple GPU (4-core graphics)  Yes  iOS 14.1, upgradable to iOS 15.2  4GB
# 3  Apple GPU (4-core graphics)  Yes    iOS 13, upgradable to iOS 15.2  3GB
# 4  Apple GPU (4-core graphics)  Yes    iOS 13, upgradable to iOS 15.2  4GB
#
#   SDCard                                                SIM  \
# 0     No  Single SIM (Nano-SIM and/or eSIM) or Dual SIM ...
# 1     No  Single SIM (Nano-SIM and/or eSIM) or Dual SIM ...
# 2     No  Single SIM (Nano-SIM and/or eSIM) or Dual SIM ...
# 3     No                               Nano-SIM and/or eSIM
# 4     No  Single SIM (Nano-SIM and/or eSIM) or Dual SIM ...
#
#                   USB                                           WLAN  \
# 0  Lightning, USB 2.0  Wi-Fi 802.11 a/b/g/n/ac/6, dual-band, hotspot
# 1  Lightning, USB 2.0  Wi-Fi 802.11 a/b/g/n/ac/6, dual-band, hotspot
# 2  Lightning, USB 2.0  Wi-Fi 802.11 a/b/g/n/ac/6, dual-band, hotspot
# 3  Lightning, USB 2.0  Wi-Fi 802.11 a/b/g/n/ac/6, dual-band, hotspot
# 4  Lightning, USB 2.0  Wi-Fi 802.11 a/b/g/n/ac/6, dual-band, hotspot
#
#   batteryCapacity  ...                                     dimensions  \
# 0         3095mAH  ...  146.7 x 71.5 x 7.7 mm (5.78 x 2.81 x 0.30 in)
# 1         3240mAH  ...  146.7 x 71.5 x 7.7 mm (5.78 x 2.81 x 0.30 in)
# 2         2815mAH  ...  146.7 x 71.5 x 7.4 mm (5.78 x 2.81 x 0.29 in)
# 3         1821mAH  ...  138.4 x 67.3 x 7.3 mm (5.45 x 2.65 x 0.29 in)
# 4         3110mAH  ...  150.9 x 75.7 x 8.3 mm (5.94 x 2.98 x 0.33 in)
#
#                                          displayType earphoneJack  \
# 0  Super Retina XDR OLED, 120Hz, HDR10, Dolby Vis...           No
# 1  Super Retina XDR OLED, HDR10, Dolby Vision, 80...           No
# 2  Super Retina XDR OLED, HDR10, Dolby Vision, 62...           No
# 3                     Retina IPS LCD, 625 nits (typ)          NaN
# 4              Liquid Retina IPS LCD, 625 nits (typ)          NaN
#
#                                       internalMemory                    name  \
# 0  128GB 6GB RAM, 256GB 6GB RAM, 512GB 6GB RAM, 1...     Apple iPhone 13 Pro
# 1        128GB 4GB RAM, 256GB 4GB RAM, 512GB 4GB RAM         Apple iPhone 13
# 2         64GB 4GB RAM, 128GB 4GB RAM, 256GB 4GB RAM         Apple iPhone 12
# 3         64GB 3GB RAM, 128GB 3GB RAM, 256GB 3GB RAM  Apple iPhone SE (2020)
# 4         64GB 4GB RAM, 128GB 4GB RAM, 256GB 4GB RAM         Apple iPhone 11
#
#                                           resolution  \
# 0  1170 x 2532 pixels, 19.5:9 ratio (~460 ppi den...
# 1  1170 x 2532 pixels, 19.5:9 ratio (~460 ppi den...
# 2  1170 x 2532 pixels, 19.5:9 ratio (~460 ppi den...
# 3   750 x 1334 pixels, 16:9 ratio (~326 ppi density)
# 4  828 x 1792 pixels, 19.5:9 ratio (~326 ppi dens...
#
#                                              sensors                 size  \
# 0  Face ID, accelerometer, gyro, proximity, compa...  6.1 inches, 90.2 cm
# 1  Face ID, accelerometer, gyro, proximity, compa...  6.1 inches, 90.2 cm
# 2  Face ID, accelerometer, gyro, proximity, compa...  6.1 inches, 90.2 cm
# 3  Fingerprint (front-mounted), accelerometer, pr...  4.7 inches, 60.9 cm
# 4  Face ID, accelerometer, gyro, proximity, compa...  6.1 inches, 90.3 cm
#
#   sourceInfo           weight
# 0   gsmarena  204 g (7.20 oz)
# 1   gsmarena  174 g (6.14 oz)
# 2   gsmarena  164 g (5.78 oz)
# 3   gsmarena  148 g (5.22 oz)
# 4   gsmarena  194 g (6.84 oz)
#
# [5 rows x 26 columns]

# %%
df_web = pd.read_csv(phoneWeb_file)
df_web.head()
# Out:
#    brand           name    price     store
# 0  apple  iPhone 13 Pro  S$1,649  Official
# 1  apple      iPhone 13  S$1,149  Official
# 2  apple      iPhone 12    S$979  Official
# 3  apple      iPhone SE    S$649  Official
# 4  apple      iPhone 11    S$799  Official

# %% [markdown]
# name field in both make it lower case

# %%
df_specs['name'] = df_specs['name'].str.lower()
df_specs.head(2)
# Out:
#                                                  CPU  \
# 0  Hexa-core (2x3.22 GHz Avalanche + 4xX.X GHz Bl...
# 1  Hexa-core (2x3.22 GHz Avalanche + 4xX.X GHz Bl...
#
#                            GPU  NFC                              OS  RAM  \
# 0  Apple GPU (5-core graphics)  Yes  iOS 15, upgradable to iOS 15.2  6GB
# 1  Apple GPU (4-core graphics)  Yes  iOS 15, upgradable to iOS 15.2  4GB
#
#   SDCard                                                SIM  \
# 0     No  Single SIM (Nano-SIM and/or eSIM) or Dual SIM ...
# 1     No  Single SIM (Nano-SIM and/or eSIM) or Dual SIM ...
#
#                   USB                                           WLAN  \
# 0  Lightning, USB 2.0  Wi-Fi 802.11 a/b/g/n/ac/6, dual-band, hotspot
# 1  Lightning, USB 2.0  Wi-Fi 802.11 a/b/g/n/ac/6, dual-band, hotspot
#
#   batteryCapacity  ...                                     dimensions  \
# 0         3095mAH  ...  146.7 x 71.5 x 7.7 mm (5.78 x 2.81 x 0.30 in)
# 1         3240mAH  ...  146.7 x 71.5 x 7.7 mm (5.78 x 2.81 x 0.30 in)
#
#                                          displayType earphoneJack  \
# 0  Super Retina XDR OLED, 120Hz, HDR10, Dolby Vis...           No
# 1  Super Retina XDR OLED, HDR10, Dolby Vision, 80...           No
#
#                                       internalMemory                 name  \
# 0  128GB 6GB RAM, 256GB 6GB RAM, 512GB 6GB RAM, 1...  apple iphone 13 pro
# 1        128GB 4GB RAM, 256GB 4GB RAM, 512GB 4GB RAM      apple iphone 13
#
#                                           resolution  \
# 0  1170 x 2532 pixels, 19.5:9 ratio (~460 ppi den...
# 1  1170 x 2532 pixels, 19.5:9 ratio (~460 ppi den...
#
#                                              sensors                 size  \
# 0  Face ID, accelerometer, gyro, proximity, compa...  6.1 inches, 90.2 cm
# 1  Face ID, accelerometer, gyro, proximity, compa...  6.1 inches, 90.2 cm
#
#   sourceInfo           weight
# 0   gsmarena  204 g (7.20 oz)
# 1   gsmarena  174 g (6.14 oz)
#
# [2 rows x 26 columns]

# %%
df_web['name'] = df_web['name'].str.lower()
df_web.head(2)
# Out:
#    brand           name    price     store
# 0  apple  iphone 13 pro  S$1,649  Official
# 1  apple      iphone 13  S$1,149  Official

# %% [markdown]
# name field in specs table separate from brand

# %%
# get the brand to a new column
df_specs['brand'] = df_specs['name'].apply(lambda row: row.split()[0])
df_specs.head(2) # rightmost column
# Out:
#                                                  CPU  \
# 0  Hexa-core (2x3.22 GHz Avalanche + 4xX.X GHz Bl...
# 1  Hexa-core (2x3.22 GHz Avalanche + 4xX.X GHz Bl...
#
#                            GPU  NFC                              OS  RAM  \
# 0  Apple GPU (5-core graphics)  Yes  iOS 15, upgradable to iOS 15.2  6GB
# 1  Apple GPU (4-core graphics)  Yes  iOS 15, upgradable to iOS 15.2  4GB
#
#   SDCard                                                SIM  \
# 0     No  Single SIM (Nano-SIM and/or eSIM) or Dual SIM ...
# 1     No  Single SIM (Nano-SIM and/or eSIM) or Dual SIM ...
#
#                   USB                                           WLAN  \
# 0  Lightning, USB 2.0  Wi-Fi 802.11 a/b/g/n/ac/6, dual-band, hotspot
# 1  Lightning, USB 2.0  Wi-Fi 802.11 a/b/g/n/ac/6, dual-band, hotspot
#
#   batteryCapacity  ...                                        displayType  \
# 0         3095mAH  ...  Super Retina XDR OLED, 120Hz, HDR10, Dolby Vis...
# 1         3240mAH  ...  Super Retina XDR OLED, HDR10, Dolby Vision, 80...
#
#   earphoneJack                                     internalMemory  \
# 0           No  128GB 6GB RAM, 256GB 6GB RAM, 512GB 6GB RAM, 1...
# 1           No        128GB 4GB RAM, 256GB 4GB RAM, 512GB 4GB RAM
#
#                   name                                         resolution  \
# 0  apple iphone 13 pro  1170 x 2532 pixels, 19.5:9 ratio (~460 ppi den...
# 1      apple iphone 13  1170 x 2532 pixels, 19.5:9 ratio (~460 ppi den...
#
#                                              sensors                 size  \
# 0  Face ID, accelerometer, gyro, proximity, compa...  6.1 inches, 90.2 cm
# 1  Face ID, accelerometer, gyro, proximity, compa...  6.1 inches, 90.2 cm
#
#   sourceInfo           weight  brand
# 0   gsmarena  204 g (7.20 oz)  apple
# 1   gsmarena  174 g (6.14 oz)  apple
#
# [2 rows x 27 columns]

# %%
# remove the brand name from the name column
try:
    df_specs['name'] = df_specs['name'].apply(lambda row: row.replace(row['brand'],'').strip()) 
except:
    pass
df_specs.head(2)
# Out:
#                                                  CPU  \
# 0  Hexa-core (2x3.22 GHz Avalanche + 4xX.X GHz Bl...
# 1  Hexa-core (2x3.22 GHz Avalanche + 4xX.X GHz Bl...
#
#                            GPU  NFC                              OS  RAM  \
# 0  Apple GPU (5-core graphics)  Yes  iOS 15, upgradable to iOS 15.2  6GB
# 1  Apple GPU (4-core graphics)  Yes  iOS 15, upgradable to iOS 15.2  4GB
#
#   SDCard                                                SIM  \
# 0     No  Single SIM (Nano-SIM and/or eSIM) or Dual SIM ...
# 1     No  Single SIM (Nano-SIM and/or eSIM) or Dual SIM ...
#
#                   USB                                           WLAN  \
# 0  Lightning, USB 2.0  Wi-Fi 802.11 a/b/g/n/ac/6, dual-band, hotspot
# 1  Lightning, USB 2.0  Wi-Fi 802.11 a/b/g/n/ac/6, dual-band, hotspot
#
#   batteryCapacity  ...                                        displayType  \
# 0         3095mAH  ...  Super Retina XDR OLED, 120Hz, HDR10, Dolby Vis...
# 1         3240mAH  ...  Super Retina XDR OLED, HDR10, Dolby Vision, 80...
#
#   earphoneJack                                     internalMemory  \
# 0           No  128GB 6GB RAM, 256GB 6GB RAM, 512GB 6GB RAM, 1...
# 1           No        128GB 4GB RAM, 256GB 4GB RAM, 512GB 4GB RAM
#
#             name                                         resolution  \
# 0  iphone 13 pro  1170 x 2532 pixels, 19.5:9 ratio (~460 ppi den...
# 1      iphone 13  1170 x 2532 pixels, 19.5:9 ratio (~460 ppi den...
#
#                                              sensors                 size  \
# 0  Face ID, accelerometer, gyro, proximity, compa...  6.1 inches, 90.2 cm
# 1  Face ID, accelerometer, gyro, proximity, compa...  6.1 inches, 90.2 cm
#
#   sourceInfo           weight  brand
# 0   gsmarena  204 g (7.20 oz)  apple
# 1   gsmarena  174 g (6.14 oz)  apple
#
# [2 rows x 27 columns]

# %% [markdown]
# try to merge the two tables together by name
