# %%
import pandas as pd
file = 'phoneSpecs.csv'
df = pd.read_csv(file)
df.head(20)
# Out:
#                                                   CPU  \
# 0   Hexa-core (2x3.22 GHz Avalanche + 4xX.X GHz Bl...
# 1   Hexa-core (2x3.22 GHz Avalanche + 4xX.X GHz Bl...
# 2   Hexa-core (2x3.1 GHz Firestorm + 4x1.8 GHz Ice...
# 3   Hexa-core (2x2.65 GHz Lightning + 4x1.8 GHz Th...
# 4   Hexa-core (2x2.65 GHz Lightning + 4x1.8 GHz Th...
# 5   Octa-core (1x2.84 GHz Kryo 680 & 3x2.42 GHz Kr...
# 6   Octa-core (1x2.99 GHz Kryo 680 & 3x2.42 GHz Kr...
# 7   Octa-core (1x2.99 GHz Kryo 680 & 3x2.42 GHz Kr...
# 8   Octa-core (1x2.84 GHz Kryo 680 & 3x2.42 GHz Kr...
# 9   Octa-core (1x2.84 GHz Kryo 680 & 3x2.42 GHz Kr...
# 10  Octa-core (1x2.84 GHz Kryo 680 & 3x2.42 GHz Kr...
# 11  Octa-core (2x2.0 GHz Kryo 560 Gold & 6x1.7 GHz...
# 12  Octa-core (1x2.84 GHz Kryo 585 & 3x2.42 GHz Kr...
# 13  Octa-core (1x2.84 GHz Kryo 585 & 3x2.42 GHz Kr...
# 14  Octa-core (4x2.0 GHz Kryo 260 Gold & 4x1.8 GHz...
#
#                             GPU  NFC  \
# 0   Apple GPU (5-core graphics)  Yes
# ...
